# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import logit
import warnings
from stats_helpers import mean_ci, cohen_d, bland_altman_plot
from scipy.stats import mannwhitneyu
warnings.filterwarnings('ignore')

# Load data
df = pd.read_excel('data.xlsx')
df['groups_idx'] = df['group']
df['updrs_diff'] = df['w24_updrsiii'] - df['w0_updrsiii']
df['seheps_diff'] = df['w8_seheps'] - df['seheps']
df['w8-w0_mep'] = df['w8_mep'] - df['w0_mep']
df['w24-w8_mep'] = df['w24_mep'] - df['w8_mep']
df['w24-w0_mep'] = df['w24_mep'] - df['w0_mep']
df['w8-24_adh'] = df['w8-24_total'] > (0.7 * 800)
df['W1_mep_diff'] = df['w0_mep'] - df['w1_mep']

# Adjust group indices
df.loc[df['group'] == 0, 'groups_idx'] = 1
df.loc[df['group'] == 1, 'groups_idx'] = 2
df['groups_idx_seheps'] = df['groups_idx']
df.loc[(df['group'] == 0) & (df['w8_seheps'] >= 59), 'groups_idx_seheps'] = 3
df.loc[(df['group'] == 1) & (df['w8_seheps'] >= 59), 'groups_idx_seheps'] = 4
display(df)
# Out:
#        ID  group gender  moca  age  duration  dopamin_therapy  led_mg  \
# 0    CG_1      0      M    29   67         5                1   450.0
# 1    CG_2      0      F    27   69        19                1   938.0
# 2    CG_3      0      F    25   60        24                1  1000.0
# 3    CG_4      0      M    25   58         9                1   450.0
# 4    CG_5      0      M    29   64         3                1   300.0
# ..    ...    ...    ...   ...  ...       ...              ...     ...
# 70  EG_33      1      M    26   77         2                1   600.0
# 71  EG_34      1      M    28   50         7                1   875.0
# 72  EG_35      1      F    26   63         7                1   750.0
# 73  EG_36      1      M    25   62         6                1   600.0
# 74  EG_37      1      M    27   54         6                1   600.0
#
#     advanced_therapies  education_years  ... w24_mep groups_idx  updrs_diff  \
# ...

# %% [markdown]
# ## Splitting into groups and basic data description
# Splitting the data into control (CG) and experimental (EG) groups, naming the groups, and basic variable description.

# %%
# Split into groups and basic description
CG = df[df['group'] == 0].copy()  # Control group
EG = df[df['group'] == 1].copy()  # Experimental group
group_names = ['CG', 'EG']
group_names_seheps = ['CG SEHEPS <59', 'EG SEHEPS <59', 'CG SEHEPS >= 59', 'EG SEHEPS >= 59']

# Basic description of selected variables
params = ['moca','age','duration','education_years','height','weight','bmi','led_mg','w0_updrsiii','seheps','w0_mep','w0_vpcf']
display(df[params].describe().applymap(lambda x: round(x, 3)))
# Out:
#          moca     age  duration  education_years   height   weight     bmi  \
# count  75.000  75.000    75.000           75.000   75.000   75.000  75.000
# mean   26.107  65.453     7.147           15.253  173.253   79.053  26.121
# std     2.934   9.154     5.208            2.886    9.023   18.778   4.662
# min    19.000  43.000     1.000            9.000  158.000   48.000  17.647
# 25%    24.000  59.000     4.000           13.000  166.000   67.500  22.903
# 50%    26.000  67.000     6.000           15.000  172.000   76.000  25.469
# 75%    29.000  71.500     8.000           18.000  179.500   90.000  29.013
# max    30.000  80.000    29.000           22.000  195.000  140.000  36.818
#
#          led_mg  w0_updrsiii  seheps   w0_mep  w0_vpcf
# count    62.000       75.000  75.000   75.000   75.000
# mean    683.194       17.267  40.240  133.413  458.493
# std     295.486        9.095  16.261   46.384  131.150
# min     150.000        2.000   9.000   47.000  113.000
# ...

# %% [markdown]
# ## Comparison of groups in demographic and clinical parameters at baseline
# Comparison of control and experimental groups using t-test for selected parameters.

# %%
from scipy.stats import fisher_exact, ttest_ind, mannwhitneyu
import numpy as np
import pandas as pd

# Baseline demographic characteristics table with SEHEPS subgroups
# Define mapping for display names and units
baseline_params = [
    ('gender', 'Sex (Male/Female)'),
    ('age', 'Age (y)'),
    ('height', 'Height (m)'),
    ('weight', 'Weight (kg)'),
    ('bmi', 'BMI'),
    ('education_years', 'Education (y)'),
    ('duration', 'Disease duration (y)'),
    ('w0_hy', 'Hoehn & Yahr'),
    ('w0_updrsiii', 'MDS-UPDRS III, ON'),
    ('moca', 'MoCa'),
    ('led_mg', 'LEDD (mg/day)'),
    ('seheps', 'SEHEPS'),
    ('w0_mep', 'Maximum expiratory pressure (cmH2O)')
]

rows = []
for col, label in baseline_params:
    if col == 'gender':
        # Count males and females for all and SEHEPS subgroups
        def count_mf(df):
            return (df['gender'] == 'M').sum(), (df['gender'] == 'F').sum()
        
        cg_m, cg_f = count_mf(CG)
        eg_m, eg_f = count_mf(EG)
        cg_m1, cg_f1 = count_mf(CG[CG['w8_seheps'] < 59])
        cg_m2, cg_f2 = count_mf(CG[CG['w8_seheps'] >= 59])
        eg_m1, eg_f1 = count_mf(EG[EG['w8_seheps'] < 59])
        eg_m2, eg_f2 = count_mf(EG[EG['w8_seheps'] >= 59])
        
        
        cg_val = f"{cg_m}/{cg_f} [ {cg_m1}/{cg_f1}; {cg_m2}/{cg_f2} ]"
        eg_val = f"{eg_m}/{eg_f} [ {eg_m1}/{eg_f1}; {eg_m2}/{eg_f2} ]"
        # Fisher's exact test for gender distribution (all)
        table = np.array([[cg_m, cg_f], [eg_m, eg_f]])
        _, p_val_gender = fisher_exact(table)
        # Fisher's exact test for SEHEPS subgroups in CG and EG
        table_cg = np.array([[cg_m1, cg_f1], [cg_m2, cg_f2]]) if (cg_m1+cg_f1>0 and cg_m2+cg_f2>0) else np.nan
        table_eg = np.array([[eg_m1, eg_f1], [eg_m2, eg_f2]]) if (eg_m1+eg_f1>0 and eg_m2+eg_f2>0) else np.nan
        pval_cg = fisher_exact(table_cg)[1] if isinstance(table_cg, np.ndarray) else np.nan
        pval_eg = fisher_exact(table_eg)[1] if isinstance(table_eg, np.ndarray) else np.nan
        row_format = [label, cg_val, eg_val, f"{p_val_gender:.3f} [{pval_cg:.3f};{pval_eg:.3f}]"]
        rows.append(row_format)
        continue
    
    
    # All values
    cg_vals = CG[col].dropna()
    eg_vals = EG[col].dropna()
    # SEHEPS subgroups
    cg1 = CG[CG['w8_seheps'] < 59][col].dropna()
    cg2 = CG[CG['w8_seheps'] >= 59][col].dropna()
    eg1 = EG[EG['w8_seheps'] < 59][col].dropna()
    eg2 = EG[EG['w8_seheps'] >= 59][col].dropna()
    # Means and SDs
    cg_mean, cg_std = cg_vals.mean(), cg_vals.std()
    eg_mean, eg_std = eg_vals.mean(), eg_vals.std()
    cg1_mean, cg1_std = cg1.mean(), cg1.std() if len(cg1)>0 else (np.nan, np.nan)
    cg2_mean, cg2_std = cg2.mean(), cg2.std() if len(cg2)>0 else (np.nan, np.nan)
    eg1_mean, eg1_std = eg1.mean(), eg1.std() if len(eg1)>0 else (np.nan, np.nan)
    eg2_mean, eg2_std = eg2.mean(), eg2.std() if len(eg2)>0 else (np.nan, np.nan)
    # Format: main [<59; ≥59]
    cg_val = f"{cg_mean:.1f} ({cg_std:.1f}) [ {cg1_mean:.1f} ({cg1_std:.1f}); {cg2_mean:.1f} ({cg2_std:.1f}) ]"
    eg_val = f"{eg_mean:.1f} ({eg_std:.1f}) [ {eg1_mean:.1f} ({eg1_std:.1f}); {eg2_mean:.1f} ({eg2_std:.1f}) ]"
    # Test for normality in subgroups
    cg1_norm = stats.kstest((cg1 - cg1.mean()) / cg1.std(ddof=0), 'norm').pvalue > 0.05 if len(cg1)>2 else False
    cg2_norm = stats.kstest((cg2 - cg2.mean()) / cg2.std(ddof=0), 'norm').pvalue > 0.05 if len(cg2)>2 else False
    eg1_norm = stats.kstest((eg1 - eg1.mean()) / eg1.std(ddof=0), 'norm').pvalue > 0.05 if len(eg1)>2 else False
    eg2_norm = stats.kstest((eg2 - eg2.mean()) / eg2.std(ddof=0), 'norm').pvalue > 0.05 if len(eg2)>2 else False
    # p-value for difference between SEHEPS subgroups in CG and EG
    if cg1_norm and eg1_norm and len(cg1)>1 and len(eg1)>1:
        _, pval_cg = ttest_ind(cg1, eg1, nan_policy='omit')
    else:
        try:
            _, pval_cg = mannwhitneyu(cg1, eg1, alternative='two-sided')
        except:
            pval_cg = np.nan
    if cg2_norm and eg2_norm and len(cg2)>1 and len(eg2)>1:
        _, pval_eg = ttest_ind(cg2, eg2, nan_policy='omit')
    else:
        try:
            _, pval_eg = mannwhitneyu(cg2, eg2, alternative='two-sided')
        except:
            pval_eg = np.nan
            
            
    # p-value for CG vs EG (all)
    cg_norm = stats.kstest((cg_vals - cg_vals.mean()) / cg_vals.std(ddof=0), 'norm').pvalue > 0.05 if len(cg_vals)>2 else False
    eg_norm = stats.kstest((eg_vals - eg_vals.mean()) / eg_vals.std(ddof=0), 'norm').pvalue > 0.05 if len(eg_vals)>2 else False
    if cg_norm and eg_norm and len(cg_vals)>1 and len(eg_vals)>1:
        _, p_val = ttest_ind(cg_vals, eg_vals, nan_policy='omit')
        normality = '*'
    else:
        try:
            _, p_val = mannwhitneyu(cg_vals, eg_vals, alternative='two-sided')
        except:
            p_val = np.nan
        normality = ''
    row_format = [
        label,
        cg_val,
        eg_val,
        f"{p_val:.3f} [{pval_cg:.3f};{pval_eg:.3f}]{normality}"
        
    ]
    rows.append(row_format)

# Create DataFrame for display
baseline_table = pd.DataFrame(
    rows,
    columns=['Measure', 'Control group (n=38) [WEEK 8 SEHEPS <59;≥59]', 'Experimental group (n=37) [WEEK 8 SEHEPS <59;≥59]', 'CG vs EG P-value [WEEK 8 SEHEPS <59;≥59]']    
)
display(baseline_table)
# Out:
#                                 Measure  \
# 0                     Sex (Male/Female)
# 1                               Age (y)
# 2                            Height (m)
# 3                           Weight (kg)
# 4                                   BMI
# 5                         Education (y)
# 6                  Disease duration (y)
# 7                          Hoehn & Yahr
# 8                     MDS-UPDRS III, ON
# 9                                  MoCa
# 10                        LEDD (mg/day)
# 11                               SEHEPS
# 12  Maximum expiratory pressure (cmH2O)
#
#       Control group (n=38) [WEEK 8 SEHEPS <59;≥59]  \
# 0                              21/17 [ 10/8; 7/6 ]
# 1            65.4 (9.5) [ 66.2 (9.0); 67.8 (9.8) ]
# 2         173.7 (8.9) [ 174.8 (8.8); 171.8 (8.4) ]
# 3         78.3 (19.2) [ 76.2 (17.0); 78.9 (17.5) ]
# 4            25.8 (5.0) [ 24.8 (4.4); 26.7 (5.4) ]
# 5            14.9 (2.9) [ 15.6 (3.0); 14.3 (2.6) ]
# ...

# %% [markdown]
# ### Linear Mixed Effects Model (LMM) for adherence
# **Linear Mixed Effects Model (LMM):**
# A linear mixed effects model was used to analyze adherence across time intervals, groups, and SEHEPS subgroups, accounting for repeated measures within subjects. The model formula was:
# $$\text{adherence} \sim \text{group} \times \text{interval} \times \text{SEHEPS group} + (1|\text{ID})$$
# where group (CG/EG), interval (W0-8/W8-24), and SEHEPS group (<59/≥59) were included as fixed effects and their interactions, and subject ID was included as a random intercept to account for within-subject correlation. Model assumptions were checked using residual diagnostics (Shapiro-Wilk and Breusch-Pagan tests).
# The model was fitted using the `statsmodels` Python package (function `mixedlm`).

# %%
import pandas as pd
import statsmodels.formula.api as smf

# Prepare data for LMM: long format for repeated measures
adherence_long = pd.melt(
    df,
    id_vars=['ID', 'group', 'w8_seheps'],
    value_vars=['w0-8_total', 'w8-24_total'],
    var_name='interval',
    value_name='adherence'
)

# Create SEHEPS group (<59 vs >=59 at week 8)
adherence_long['seheps_group'] = (adherence_long['w8_seheps'] >= 59).astype(int)

# Categorical variables for model
adherence_long['interval'] = adherence_long['interval'].map({'w0-8_total': 'W0-8', 'w8-24_total': 'W8-24'})
adherence_long['group'] = adherence_long['group'].map({0: 'CG', 1: 'EG'})
adherence_long['seheps_group'] = adherence_long['seheps_group'].map({0: '<59', 1: '≥59'})

# Remove missing adherence values
adherence_long = adherence_long.dropna(subset=['adherence'])

# Fit the LMM: adherence ~ group * interval * seheps_group + (1|ID)
model = smf.mixedlm(
    'adherence ~ group * interval * seheps_group',
    data=adherence_long,
    groups=adherence_long['ID']
)
result = model.fit(reml=False)
print(result.summary())
# Out:
#                               Mixed Linear Model Regression Results
# ...
# Model:                           MixedLM              Dependent Variable:              adherence
# No. Observations:                126                  Method:                          ML
# No. Groups:                      67                   Scale:                           156256.9626
# Min. group size:                 1                    Log-Likelihood:                  -935.2249
# Max. group size:                 2                    Converged:                       Yes
# Mean group size:                 1.9
# --------------------------------------------------------------------------------------------------
#                                                    Coef.   Std.Err.   z    P>|z|  [0.025   0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                                          942.000   92.925 10.137 0.000  759.870 1124.130
# ...

# %% [markdown]
# **Main findings from the model:**
#
# Intercept (942.0):
# The estimated mean adherence in the reference group (Control Group, interval W0-8, SEHEPS <59). This value is statistically significant.
#
# group[T.EG] (50.3, p=0.70):
# The difference in adherence between the Experimental Group (EG) and Control Group (CG) in the W0-8 interval and SEHEPS <59. This difference is not statistically significant.
#
# interval[T.W8-24] (-416.8, p=0.002):
# Adherence in the W8-24 interval is significantly lower than in W0-8 (for CG, SEHEPS <59).
#
# seheps_group[T.≥59] (27.6, p=0.85):
# The difference in adherence between SEHEPS ≥59 and <59 (for CG, W0-8) is not significant.
#
# Interactions:
#
# group[T.EG]:interval[T.W8-24] (497.0, p=0.008):
# The difference in adherence between EG and CG is significantly greater in the W8-24 interval compared to W0-8 (for SEHEPS <59). This means EG maintains higher adherence than CG in the later interval.
#
# group[T.EG]:seheps_group[T.≥59] (-15.9, p=0.94):
# The interaction between group and SEHEPS is not significant.
#
# interval[T.W8-24]:seheps_group[T.≥59] (567.1, p=0.006):
# The difference in adherence between intervals (W8-24 vs W0-8) is significantly larger for patients with SEHEPS ≥59.
#
# group[T.EG]:interval[T.W8-24]:seheps_group[T.≥59] (-426.5, p=0.14):
# The three-way interaction is not statistically significant.
#
# Random effect:
#
# Group Var (7809.1):
# This is the estimated variance in adherence between individual subjects (ID), after accounting for the fixed effects.
# Summary:
#
# Adherence generally decreases in the later interval (W8-24), but this decrease is less pronounced in the Experimental Group.
# The Experimental Group shows significantly higher adherence than the Control Group in the W8-24 interval.
# The difference in adherence between intervals is even greater for patients with SEHEPS ≥59.
# Other effects and interactions are not statistically significant.
#
# **Conclusion:**
# The intervention (EG) helps maintain higher adherence in the later phase, especially compared to the control group, and the effect of time interval is more pronounced in patients with higher SEHEPS scores.

# %%
# --- Diagnostics: Check LMM assumptions (normality, homoscedasticity of residuals) ---
import matplotlib.pyplot as plt
import scipy.stats as stats
from statsmodels.stats.diagnostic import het_breuschpagan

# Get residuals
resid = result.resid
fitted = result.fittedvalues

# 1. QQ plot for normality
plt.figure(figsize=(5, 4))
stats.probplot(resid, dist="norm", plot=plt)
plt.title("QQ plot of LMM residuals")
plt.show()

# 2. Histogram of residuals
plt.figure(figsize=(5, 4))
plt.hist(resid, bins=20, edgecolor='k', alpha=0.7)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Histogram of LMM residuals")
plt.show()

# 3. Shapiro-Wilk test for normality
shapiro_stat, shapiro_p = stats.shapiro(resid)
print(f"Shapiro-Wilk test: W={shapiro_stat:.3f}, p={shapiro_p:.3g}")

# 4. Plot residuals vs fitted values (check for homoscedasticity)
plt.figure(figsize=(5, 4))
plt.scatter(fitted, resid, alpha=0.7)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.title("Residuals vs Fitted values")
plt.show()

# 5. Breusch-Pagan test for heteroscedasticity
bp_test = het_breuschpagan(resid, result.model.exog)
print(f"Breusch-Pagan test: LM stat={bp_test[0]:.2f}, p={bp_test[1]:.3g}")
# Out:
# Shapiro-Wilk test: W=0.775, p=1.25e-12
# Breusch-Pagan test: LM stat=17.22, p=0.016

# %% [markdown]
# **Diagnostics summary:**
#
# - **Shapiro-Wilk test:** p < 0.001 → The residuals are not normally distributed.
# - **Breusch-Pagan test:** p = 0.016 → There is evidence of heteroscedasticity (the variance of the residuals is not constant).
#
# **Impact:** The model results should be interpreted with caution, as the assumptions of normality and homoscedasticity of residuals are not fully met. Robust estimates or data transformation may be considered, or the results can be supplemented with a sensitivity analysis.

# %% [markdown]
# ## Post-hoc analysis

# %%
test_table = []
intervals = ['w8-12', 'w12-16', 'w16-20', 'w20-24']
for w in intervals:
    cg_vals = CG[w].dropna()
    eg_vals = EG[w].dropna()
    n_cg = len(cg_vals)
    n_eg = len(eg_vals)
    mean_cg = cg_vals.mean()
    std_cg = cg_vals.std()
    mean_eg = eg_vals.mean()
    std_eg = eg_vals.std()
    # t-test
    stat, p_val = mannwhitneyu(cg_vals, eg_vals, alternative='two-sided')
    
    # Cohen's d
    d, d_ci = cohen_d(cg_vals, eg_vals)
    test_table.append([
        w.replace('w', 'W').replace('_', '-'),
        n_cg, f"{mean_cg:.1f} ({std_cg:.1f})",
        n_eg, f"{mean_eg:.1f} ({std_eg:.1f})",
        f"{p_val:.3f}", f"{d:.2f}", f"{d_ci[0]:.2f} to {d_ci[1]:.2f}"
    ])

ttest_df = pd.DataFrame(
    test_table,
    columns=[
        "Interval",
        "CG n", "CG Mean (SD)",
        "EG n", "EG Mean (SD)",
        "P-value", "Cohen d", "Cohen d 95% CI"
    ]
)
display(ttest_df)



# Prepare data for boxplots using seaborn with jittered points
cg_weeks = ['w8-12', 'w12-16', 'w16-20', 'w20-24']
eg_weeks = ['w8-12', 'w12-16', 'w16-20', 'w20-24']

# Prepare long-form DataFrame for seaborn
plot_data = []
for i, w in enumerate(cg_weeks):
    for val in CG[w].dropna():
        plot_data.append({'Group': 'CG', 'Week': w, 'Value': val})
for i, w in enumerate(eg_weeks):
    for val in EG[w].dropna():
        plot_data.append({'Group': 'EG', 'Week': w, 'Value': val})
plot_df = pd.DataFrame(plot_data)

# Create a combined label for plotting
plot_df['Label'] = plot_df['Group'] + ' ' + plot_df['Week']

# Define custom palette: CG = blue, EG = orange
cg_color = '#4C72B0'  # blue
eg_color = '#FF9900'  # orange
labels = [f'CG {w}' for w in cg_weeks] + [f'EG {w}' for w in eg_weeks]
palette = [cg_color]*4 + [eg_color]*4

plt.figure(figsize=(7, 6))  # Reduce width to bring boxplots closer
ax = sns.boxplot(
    x='Label', y='Value', data=plot_df, order=labels, palette=palette,
    showmeans=False, boxprops=dict(alpha=.7), width=0.35
)
sns.stripplot(
    x='Label', y='Value', data=plot_df, order=labels, color='black',
    size=4, jitter=0.25, alpha=0.5, ax=ax
)


# Red dashed line at y=250
plt.axhline(250, color='red', linestyle='--', linewidth=2, label='Prescribed number of expiratory maneuvers')

# Set x-axis labels vertical
ax.set_xticklabels(labels, rotation=90)

ax.set_ylabel('Number of Expiratory Maneuvers (MEP)')
ax.legend(loc='upper right')

# Draw line and annotate p-value and Cohen's d between CG W20-24 and EG W20-24
x1, x2 = 3, 7  # CG W20-24 and EG W20-24 (0-based index)
y, h = max(plot_df[plot_df['Label'] == 'CG w20-24']['Value'].max(),
           plot_df[plot_df['Label'] == 'EG w20-24']['Value'].max()) + 30, 20
ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], color='black')
ax.text((x1+x2)/2, y+h+5, "p=0.019, cohen d=0.67", ha='center', va='bottom', fontsize=12)

ax.grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
#   Interval  CG n   CG Mean (SD)  EG n   EG Mean (SD) P-value Cohen d  \
# 0    W8-12    29  215.8 (130.3)    30  296.2 (167.6)   0.057    0.53
# 1   W12-16    29  194.7 (143.2)    30  306.4 (202.8)   0.018    0.63
# 2   W16-20    29  182.9 (159.3)    30  275.6 (197.1)   0.036    0.52
# 3   W20-24    29  151.9 (151.7)    30  260.4 (170.6)   0.013    0.67
#
#   Cohen d 95% CI
# 0   0.01 to 1.05
# 1   0.11 to 1.16
# 2  -0.00 to 1.04
# 3   0.15 to 1.20

# %% [markdown]
# ### Overall adherence (All patients)

# %%
from scipy.stats import mannwhitneyu
import numpy as np
import pandas as pd
from stats_helpers import mean_ci, cohen_d

# Helper for row formatting
def row_format1(group, n, mean, std, ci, pval=None, d=None, dci=None):
    r = [group, n, f"{mean:.0f}", f"{std:.1f}", f"[{ci[0]:.0f}, {ci[1]:.0f}]"]
    if pval is not None:
        r.append(f"{pval:.2f}")
    else:
        r.append("")
    if d is not None:
        r.append(f"{d:.2f}")
        r.append(f"[{dci[0]:.2f}, {dci[1]:.2f}]")
    else:
        r.append("")
        r.append("")
    return r


table_oa = []
columns = ["Time interval", "Group", "n", "Mean", "SD", "95% CI", "P-value", "Cohen d", "Cohen d 95% CI" ]

# W0-8
cg0 = CG['w0-8_total'].dropna()
eg0 = EG['w0-8_total'].dropna()
mean_cg0, std_cg0, n_cg0, ci_cg0 = mean_ci(cg0)
mean_eg0, std_eg0, n_eg0, ci_eg0 = mean_ci(eg0)
stat0, p0 = mannwhitneyu(cg0, eg0, alternative='two-sided')
d0, d0ci = cohen_d(cg0, eg0)
table_oa.append(["W0-8", "CG"] + row_format1("CG", n_cg0, mean_cg0, std_cg0, ci_cg0, p0, d0, d0ci)[1:])
table_oa.append(["", "EG"] + row_format1("EG", n_eg0, mean_eg0, std_eg0, ci_eg0)[1:])

# W8-24
cg1 = CG['w8-24_total'].dropna()
eg1 = EG['w8-24_total'].dropna()
mean_cg1, std_cg1, n_cg1, ci_cg1 = mean_ci(cg1)
mean_eg1, std_eg1, n_eg1, ci_eg1 = mean_ci(eg1)
stat1, p1 = mannwhitneyu(cg1, eg1, alternative='two-sided')
d1, d1ci = cohen_d(cg1, eg1)
table_oa.append(["W8-24", "CG"] + row_format1("CG", n_cg1, mean_cg1, std_cg1, ci_cg1, p1, d1, d1ci)[1:])
table_oa.append(["", "EG"] + row_format1("EG", n_eg1, mean_eg1, std_eg1, ci_eg1)[1:])

adherence_table = pd.DataFrame(table_oa, columns=columns)
display(adherence_table)
# Out:
#   Time interval Group   n  Mean     SD       95% CI P-value Cohen d  \
# 0          W0-8    CG  32   953   83.2   [924, 982]    0.05    0.49
# 1                  EG  35   998   95.7  [966, 1029]
# 2         W8-24    CG  29   771  538.4   [575, 967]    0.02    0.58
# 3                  EG  30  1139  712.0  [884, 1393]
#
#   Cohen d 95% CI
# 0   [0.01, 0.98]
# 1
# 2   [0.06, 1.10]
# 3

# %% [markdown]
# ### Adherence analysis based on SEHEPS at Week 8

# %%
table_sh = []
cg_s1 = CG[CG['w8_seheps'] < 59]['w8-24_total'].dropna()
eg_s1 = EG[EG['w8_seheps'] < 59]['w8-24_total'].dropna()
mean_cg_s1, std_cg_s1, n_cg_s1, ci_cg_s1 = mean_ci(cg_s1)
mean_eg_s1, std_eg_s1, n_eg_s1, ci_eg_s1 = mean_ci(eg_s1)
stat_s1, p_s1 = mannwhitneyu(cg_s1, eg_s1, alternative='two-sided')
d_s1, dci_s1 = cohen_d(cg_s1, eg_s1)
table_sh.append(["W8-24", "CG SEHEPS <59"] + row_format1("CG SEHEPS <59", n_cg_s1, mean_cg_s1, std_cg_s1, ci_cg_s1, p_s1, d_s1, dci_s1)[1:])
table_sh.append(["", "EG SEHEPS <59"] + row_format1("EG SEHEPS <59", n_eg_s1, mean_eg_s1, std_eg_s1, ci_eg_s1)[1:])

# >=59
cg_s2 = CG[CG['w8_seheps'] >= 59]['w8-24_total'].dropna()
eg_s2 = EG[EG['w8_seheps'] >= 59]['w8-24_total'].dropna()
mean_cg_s2, std_cg_s2, n_cg_s2, ci_cg_s2 = mean_ci(cg_s2)
mean_eg_s2, std_eg_s2, n_eg_s2, ci_eg_s2 = mean_ci(eg_s2)
stat_s2, p_s2 = mannwhitneyu(cg_s2, eg_s2, alternative='two-sided')
d_s2, dci_s2 = cohen_d(cg_s2, eg_s2)
table_sh.append(["W8-24", "CG SEHEPS ≥59"] + row_format1("CG SEHEPS ≥59", n_cg_s2, mean_cg_s2, std_cg_s2, ci_cg_s2, p_s2, d_s2, dci_s2)[1:])
table_sh.append(["", "EG SEHEPS ≥59"] + row_format1("EG SEHEPS ≥59", n_eg_s2, mean_eg_s2, std_eg_s2, ci_eg_s2)[1:])

adherence_table = pd.DataFrame(table_sh, columns=columns)
display(adherence_table)
# Out:
#   Time interval          Group   n  Mean     SD        95% CI P-value Cohen d  \
# 0         W8-24  CG SEHEPS <59  17   525  350.8    [358, 692]    0.04    0.80
# 1                EG SEHEPS <59  17  1073  903.0   [643, 1502]
# 2         W8-24  CG SEHEPS ≥59  12  1120  576.6   [794, 1446]    0.34    0.22
# 3                EG SEHEPS ≥59  13  1225  351.6  [1034, 1416]
#
#   Cohen d 95% CI
# 0   [0.10, 1.50]
# 1
# 2  [-0.57, 1.01]
# 3

# %% [markdown]
# ### Four-Week Interval adherence analysis in patients at risk of non-adherence (SEHEPS <59)

# %%
table_fw = []
at_risk_CG = CG[CG['w8_seheps'] < 59]
at_risk_EG = EG[EG['w8_seheps'] < 59]
intervals = ['w8-12', 'w12-16', 'w16-20', 'w20-24']
for w in intervals:
    cg_w = at_risk_CG[w].dropna()
    eg_w = at_risk_EG[w].dropna()
    mean_cg, std_cg, n_cg, ci_cg = mean_ci(cg_w)
    mean_eg, std_eg, n_eg, ci_eg = mean_ci(eg_w)
    stat, p = mannwhitneyu(cg_w, eg_w, alternative='two-sided')
    d, dci = cohen_d(cg_w, eg_w)
    table_fw.append([w.replace('w', 'W').replace('_', '-'), "CG"] + row_format1("CG", n_cg, mean_cg, std_cg, ci_cg, p, d, dci)[1:])
    table_fw.append(["", "EG"] + row_format1("EG", n_eg, mean_eg, std_eg, ci_eg)[1:])

adherence_table = pd.DataFrame(table_fw, columns=columns)
display(adherence_table)
# Out:
#   Time interval Group   n Mean     SD      95% CI P-value Cohen d  \
# 0         W8-12    CG  17  165   98.4  [118, 212]    0.15    0.70
# 1                  EG  17  277  204.3  [180, 374]
# 2        W12-16    CG  17  135  107.6   [84, 186]    0.04    0.84
# 3                  EG  17  301  257.9  [178, 423]
# 4        W16-20    CG  17  107  117.5   [51, 163]    0.06    0.75
# 5                  EG  17  255  252.4  [135, 375]
# 6        W20-24    CG  17   74   90.3   [31, 116]    0.01    1.03
# 7                  EG  17  240  208.4  [141, 339]
#
#   Cohen d 95% CI
# 0   [0.01, 1.40]
# 1
# 2   [0.14, 1.54]
# 3
# 4   [0.05, 1.45]
# 5
# 6   [0.32, 1.75]
# 7

# %% [markdown]
# - From baseline to week 8, the mean SEHEPS score significantly increased by **11.2 points** (SD 13.6, 95% CI [6.36, 15.96]; P<0.001) in the control group and by **14.5 points** (SD 14.0, 95% CI [9.91, 19.2]; P<0.001) in the experimental group.

# %% [markdown]
# ### Overall Changes in MEP and Subgroup Analysis Based on SEHEPS at Weekly Intervals

# %%
import numpy as np
import pandas as pd
from scipy.stats import  ttest_ind
from stats_helpers import mean_ci, cohen_d
from scipy.stats import ttest_rel

rows = []
def row_format2(
    interval, group, stats,g_pval=None, g_d=None, g_d_ci=None):
    row = [interval, group, stats['n'],
           f"{stats['mean_pre']:.1f} ({stats['std_pre']:.1f})", f"{stats['mean_post']:.1f} ({stats['std_post']:.1f})",
           f"{stats['mean_diff']:+.1f} ({stats['std_diff']:.1f})", f"[{stats['ci_diff'][0]:.1f}, {stats['ci_diff'][1]:.1f}]",
           f"{stats['pval']:.3f}",
           f"{stats['d']:.2f} [{stats['d_ci'][0]:.2f}, {stats['d_ci'][1]:.2f}]"
    ]
    if g_pval is not None:
        row.append(f"{g_pval:.3f}")
    else:
        row.append("")
    if g_d is not None and g_d_ci is not None:
        row.append(f"{g_d:.2f} [{g_d_ci[0]:.2f}, {g_d_ci[1]:.2f}]")
    else:
        row.append("")
    return row

# Helper to get stats from precomputed columns
def stats_from_diff(pre, post, diff):
    # Only keep entries where diff is not nan
    mask = ~diff.isna()
    pre = pre[mask]
    post = post[mask]
    diff = diff[mask]
    n = pre.count()
    mean_pre = pre.mean()
    std_pre = pre.std()
    mean_post = post.mean()
    std_post = post.std()
    mean_diff = diff.mean()
    std_diff = diff.std()
    ci_diff = mean_ci(diff)[3]
    # Párový t-test pre vs post
    pval = ttest_rel(pre, post, nan_policy='omit')[1]
    # Cohen's d pro párový rozdíl
    d = (mean_post - mean_pre) / np.sqrt((std_pre ** 2 + std_post ** 2) / 2)
    # CI pro Cohen's d (přibližně, 95%)
    se_d = np.sqrt((1/n) + (d**2/(2*n)))
    d_ci = (d - 1.96 * se_d, d + 1.96 * se_d)
    return {
        'n': n,
        'mean_pre': mean_pre,
        'std_pre': std_pre,
        'mean_post': mean_post,
        'std_post': std_post,
        'mean_diff': mean_diff,
        'std_diff': std_diff,
        'ci_diff': ci_diff,
        'pval': pval,
        'd': d,
        'd_ci': d_ci
    }

# Overall changes in MEP
# W0-W8
cg_stats = stats_from_diff(CG['w0_mep'], CG['w8_mep'], CG['w8-w0_mep'])
eg_stats = stats_from_diff(EG['w0_mep'], EG['w8_mep'], EG['w8-w0_mep'])



d, d_ci = cohen_d(CG['w8-w0_mep'], EG['w8-w0_mep'])
pval_between = ttest_ind(CG['w8-w0_mep'], EG['w8-w0_mep'], nan_policy='omit')[1]
rows.append(row_format2('W0-W8', 'CG', cg_stats, pval_between, d, d_ci))
rows.append(row_format2('', 'EG', eg_stats))


# W8-W24
cg_stats = stats_from_diff(CG['w8_mep'], CG['w24_mep'], CG['w24-w8_mep'])
eg_stats = stats_from_diff(EG['w8_mep'], EG['w24_mep'], EG['w24-w8_mep'])

d, d_ci = cohen_d(CG['w24-w8_mep'], EG['w24-w8_mep'])
pval_between = ttest_ind(CG['w24-w8_mep'], EG['w24-w8_mep'], nan_policy='omit')[1]
rows.append(row_format2('W8-W24', 'CG', cg_stats, pval_between, d, d_ci))
rows.append(row_format2('', 'EG', eg_stats))


# W0-W24

cg_stats = stats_from_diff(CG['w0_mep'], CG['w24_mep'], CG['w24-w0_mep'])
eg_stats = stats_from_diff(EG['w0_mep'], EG['w24_mep'], EG['w24-w0_mep'])

d, d_ci = cohen_d(CG['w24-w0_mep'], EG['w24-w0_mep'])
pval_between = ttest_ind(CG['w24-w0_mep'], EG['w24-w0_mep'], nan_policy='omit')[1]
rows.append(row_format2('W0-W24', 'CG', cg_stats, pval_between, d, d_ci))
rows.append(row_format2('', 'EG', eg_stats))


# Subgroup Analysis Based on SEHEPS at Week 8
# W8-W24, SEHEPS <59
cg_sub = CG[CG['w8_seheps'] < 59]
eg_sub = EG[EG['w8_seheps'] < 59]
cg_stats = stats_from_diff(cg_sub['w8_mep'], cg_sub['w24_mep'], cg_sub['w24-w8_mep'])
eg_stats = stats_from_diff(eg_sub['w8_mep'], eg_sub['w24_mep'], eg_sub['w24-w8_mep'])

d, d_ci = cohen_d(cg_sub['w24-w8_mep'], eg_sub['w24-w8_mep'])
pval_between = ttest_ind(cg_sub['w24-w8_mep'], eg_sub['w24-w8_mep'], nan_policy='omit')[1]
rows.append(row_format2('W8-W24', 'CG SEHEPS <59', cg_stats, pval_between, d, d_ci))
rows.append(row_format2('', 'EG SEHEPS <59', eg_stats))


# W8-W24, SEHEPS >=59
cg_sub = CG[CG['w8_seheps'] >= 59]
eg_sub = EG[EG['w8_seheps'] >= 59]
cg_stats = stats_from_diff(cg_sub['w8_mep'], cg_sub['w24_mep'], cg_sub['w24-w8_mep'])
eg_stats = stats_from_diff(eg_sub['w8_mep'], eg_sub['w24_mep'], eg_sub['w24-w8_mep'])
pval_between = ttest_ind(cg_sub['w24-w8_mep'], eg_sub['w24-w8_mep'], nan_policy='omit')[1]
d, d_ci = cohen_d(cg_sub['w24-w8_mep'], eg_sub['w24-w8_mep'])
rows.append(row_format2('W8-W24', 'CG SEHEPS ≥59', cg_stats, pval_between, d, d_ci))
rows.append(row_format2('', 'EG SEHEPS ≥59', eg_stats))

columns = ['Interval', 'Group', 'n', 'Pre- Mean (SD)', 'Post- Mean (SD)', 'Mean (SD) Δ', '95% CI Δ', 'P-value  Δ','Cohen d (95% CI) Δ','P-value EG vs CG', 'Cohen d (95% CI) EG vs CG']
table3 = pd.DataFrame(rows, columns=columns)
display(table3)
# Out:
#   Interval          Group   n Pre- Mean (SD) Post- Mean (SD)   Mean (SD) Δ  \
# 0    W0-W8             CG  31   131.5 (48.2)    159.9 (50.3)  +28.4 (25.8)
# 1                      EG  35   135.7 (43.4)    178.1 (51.7)  +42.3 (25.9)
# 2   W8-W24             CG  29   161.3 (50.4)    154.6 (42.6)   -6.8 (22.4)
# 3                      EG  30   179.7 (51.1)    179.9 (52.8)   +0.1 (13.7)
# 4   W0-W24             CG  29   131.8 (48.9)    154.6 (42.6)  +22.8 (24.7)
# 5                      EG  30   136.8 (41.4)    179.9 (52.8)  +43.1 (29.9)
# 6   W8-W24  CG SEHEPS <59  17   168.1 (53.4)    153.5 (45.4)  -14.6 (21.0)
# 7           EG SEHEPS <59  17   180.1 (49.9)    177.9 (50.7)   -2.2 (11.3)
# 8   W8-W24  CG SEHEPS ≥59  12   151.8 (46.4)    156.1 (40.0)   +4.2 (20.4)
# 9           EG SEHEPS ≥59  13   179.2 (54.5)    182.5 (57.5)   +3.2 (16.3)
#
#         95% CI Δ P-value  Δ   Cohen d (95% CI) Δ P-value EG vs CG  \
# 0   [19.3, 37.5]      0.000    0.58 [0.20, 0.96]            0.033
# ...

# %% [markdown]
# **Main results for MEP changes**
# - From baseline to week 8, MEP increased by **28.4 cmH₂O** in the control group (P<0.001, Cohen d=0.60) and by **42.3 cmH₂O** in the experimental group (P<0.001, Cohen d=0.89), with the experimental group showing significantly greater improvement (**P=0.03, Cohen d=0.54**).

# %% [markdown]
# ### Seheps changes in W0 and W8

# %%
from scipy.stats import ttest_rel
import pandas as pd
import numpy as np
from stats_helpers import mean_ci, cohen_d

results = []
for group_name, group_df in zip(group_names, [CG, EG]):
    valid_seheps = group_df[['seheps', 'w8_seheps']].dropna()
    n = len(valid_seheps)
    mean_pre = valid_seheps['seheps'].mean()
    std_pre = valid_seheps['seheps'].std()
    mean_post = valid_seheps['w8_seheps'].mean()
    std_post = valid_seheps['w8_seheps'].std()
    diff = valid_seheps['w8_seheps'] - valid_seheps['seheps']
    mean_diff = diff.mean()
    std_diff = diff.std()
    ci_diff = mean_ci(diff)[3]
    pval = ttest_rel(valid_seheps['seheps'], valid_seheps['w8_seheps'])[1]
    d, d_ci = cohen_d(valid_seheps['seheps'], valid_seheps['w8_seheps'])
    results.append([
        group_name, n,
        f"{mean_pre:.1f} ({std_pre:.1f})",
        f"{mean_post:.1f} ({std_post:.1f})",
        f"{mean_diff:+.1f} ({std_diff:.1f})",
        f"[{ci_diff[0]:.1f}, {ci_diff[1]:.1f}]",
        f"{pval:.3g}",
        f"{d:.2f} [{d_ci[0]:.2f}, {d_ci[1]:.2f}]"
    ])

table = pd.DataFrame(results, columns=[
    "Group", "n", "SEHEPS baseline (Mean, SD)", "SEHEPS week 8 (Mean, SD)",
    "Mean (SD) Δ", "95% CI Δ", "P-value Δ", "Cohen d (95% CI) Δ"
])

display(table)

# Compute and display independent t-test for SEHEPS change CG vs EG
from scipy.stats import ttest_ind

# Calculate SEHEPS change for each group
cg_change = CG[['seheps', 'w8_seheps']].dropna()
eg_change = EG[['seheps', 'w8_seheps']].dropna()
cg_diff = cg_change['w8_seheps'] - cg_change['seheps']
eg_diff = eg_change['w8_seheps'] - eg_change['seheps']

# Independent t-test
stat, pval_cg_vs_eg = ttest_ind(cg_diff, eg_diff, nan_policy='omit')
print(f"T-test SEHEPS change CG vs EG:  p={pval_cg_vs_eg:.3g}")
# Out:
#   Group   n SEHEPS baseline (Mean, SD) SEHEPS week 8 (Mean, SD)   Mean (SD) Δ  \
# 0    CG  31                39.3 (16.0)              50.5 (15.8)  +11.2 (13.6)
# 1    EG  35                38.9 (17.1)              53.5 (14.6)  +14.5 (14.0)
#
#       95% CI Δ P-value Δ Cohen d (95% CI) Δ
# 0  [6.4, 16.0]  8.03e-05  0.70 [0.19, 1.22]
# 1  [9.9, 19.2]  5.55e-07  0.91 [0.42, 1.41]
# T-test SEHEPS change CG vs EG:  p=0.325

# %% [markdown]
# **Main results SEHEPS changes (Baseline to Week 8):**
# - From baseline to week 8, the mean SEHEPS score significantly increased by **11.2 points** (SD 13.6, 95% CI [6.36, 15.96]; P<0.001) in the control group and by **14.5 points** (SD 14.0, 95% CI [9.91, 19.2]; P<0.001) in the experimental group.

# %% [markdown]
# ### Correlation of adherence (w8-24_total) vs SEHEPS (w8_seheps) for all groups

# %%
from scipy.stats import spearmanr, pearsonr
import matplotlib.pyplot as plt
import numpy as np
# Correlation of adherence (w8-24_total) vs SEHEPS (w8_seheps) for all groups
valid = df[['w8-24_total', 'w8_seheps']].dropna()
rho, pval = spearmanr(valid['w8-24_total'], valid['w8_seheps'])
r, p_pearson = pearsonr(valid['w8-24_total'], valid['w8_seheps'])

print(f"Correlation adherence vs SEHEPS (all groups):")
print(f"Spearman rho = {rho:.3f}, p = {pval:.3g}")
print(f"Pearson r = {r:.3f}, p = {p_pearson:.3g}")

# Additional statistics
print(f"Number of data points: {len(valid)}")
print(f"Mean adherence: {valid['w8-24_total'].mean():.1f} ± {valid['w8-24_total'].std():.1f}")
print(f"Mean SEHEPS: {valid['w8_seheps'].mean():.1f} ± {valid['w8_seheps'].std():.1f}")

# Plot
plt.figure(figsize=(7, 5))
plt.scatter(valid['w8-24_total'], valid['w8_seheps'], alpha=0.7)
slope, intercept = np.polyfit(valid['w8-24_total'], valid['w8_seheps'], 1)
x_vals = np.array([valid['w8-24_total'].min(), valid['w8-24_total'].max()])
y_vals = slope * x_vals + intercept
plt.plot(x_vals, y_vals, color='red', linestyle='--', label=f'Linear fit (r={r:.2f})')
plt.xlabel('Adherence (w8-24_total)')
plt.ylabel('SEHEPS (w8_seheps)')
plt.title('Adherence vs SEHEPS (všechny skupiny)')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# Correlation adherence vs SEHEPS (all groups):
# Spearman rho = 0.537, p = 1.15e-05
# Pearson r = 0.359, p = 0.00521
# Number of data points: 59
# Mean adherence: 958.0 ± 654.0
# Mean SEHEPS: 52.1 ± 14.9
